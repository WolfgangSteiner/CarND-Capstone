# %% [markdown]
# Traffic Light Detector Node CNN Experiments
# ======
#
# These is the R&N notebook for the traffic light detector node
# The network is trained on 64x64 samples in 4 classes (nothing, red, green, yellow)
#
# Henrik Tünnermann

# %%
import glob
import numpy as np
import cv2

# %%
nothing = glob.glob("../traffic/nothing/*.jpg")
redlights = glob.glob("../traffic/redlights/*.jpg")

greenlights = glob.glob("../traffic/greenlights/*.jpg")
yellowlights = glob.glob("../traffic/yellowlights/*.jpg")


Y = np.concatenate([np.ones(len(redlights)), np.zeros(len(nothing))-1])
Y = np.concatenate([np.array([[1,0,0,0]]*len(nothing)), 
                    np.array([[0,1,0,0]]*len(redlights)),
                    np.array([[0,0,1,0]]*len(greenlights)),
                    np.array([[0,0,0,1]]*len(yellowlights))
                   ])

# Read X Vector
X = []
for name in nothing:    
    X.append(cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB))
    
for name in redlights:    
    X.append(cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB))
    
for name in greenlights:    
    X.append(cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB))
    
for name in yellowlights:    
    X.append(cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB))

X = np.array(X)

# %%
# %pylab inline 
imshow(X[0])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### After loading I do the usual pre-processing
#
# I do not use a validation split, but I have to validate that the model works well in localization independently anyway.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.10, random_state=42)


X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
input_shape =  (3,64,64)
# Out:
# ('X_train shape:', (1498, 64, 64, 3))
# (1498, 'train samples')
# (167, 'test samples')

# %%
import tensorflow as tf
import numpy as np

def model(data, train):
    norm = data/127.5 - 1
    c1 = tf.layers.conv2d(norm, 16, 3, strides=(1, 1), padding='SAME',
                            kernel_initializer=tf.truncated_normal_initializer(stddev=0.001), activation=tf.nn.relu)
    c2 = tf.layers.conv2d(c1, 16, 3, strides=(1, 1), padding='SAME',
                            kernel_initializer=tf.truncated_normal_initializer(stddev=0.001), activation=tf.nn.relu)
    p = tf.layers.max_pooling2d(c2, 8, strides=(8,8), padding='SAME')
    
    drop1 = tf.layers.dropout(p,rate=0.25,training=train)
    
    c3 = tf.layers.conv2d(drop1, 128, 8, strides=(1, 1), padding='VALID',
        kernel_initializer=tf.truncated_normal_initializer(stddev=0.001), activation=tf.nn.relu)
    
    drop2 = tf.layers.dropout(c3,rate=0.50,training=train)
    c4 = tf.layers.conv2d(drop2, 4, 1, strides=(1, 1), padding='VALID',
        kernel_initializer=tf.truncated_normal_initializer(stddev=0.001))
    sm = tf.nn.softmax(c4, name="output")
    return c4,sm
    
def loss(data, correct_label):    
    logits = tf.reshape(data,(-1,4),name='logits')
    labels = tf.reshape(correct_label,(-1,4),name='lables')
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
    train_op = tf.train.AdamOptimizer(0.001).minimize(loss)
    
    correct_prediction = tf.equal(tf.argmax(logits,1), tf.argmax(labels,1))
    tf_accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
    return loss,train_op,tf_accuracy



testdata = (cv2.cvtColor(cv2.imread("../images/just00151.jpg"), cv2.COLOR_BGR2RGB))

batches = (int(np.ceil(X_train.shape[0]/64.)))


with tf.Session() as sess:
    
    
    tf_data = tf.placeholder(tf.float32, shape=(None, None, None, 3), name="image_input")
    tf_labels = tf.placeholder(tf.float32, shape=(None),name="labels_input")
    tf_train = tf.placeholder(tf.bool,name="train_input")
    
    modelout,sm = model(tf_data, tf_train)
    l,train_op, tf_accuracy = loss(modelout, tf_labels)

    sess.run(tf.global_variables_initializer())
    
    for epoch_i in range(100):
        for batch_i in range(batches):
            train_loss, _, accuracy = sess.run([l, train_op, tf_accuracy],
                        feed_dict={tf_data: X_train[batch_i*64:batch_i*64+64], 
                                   tf_labels: Y_train[batch_i*64:batch_i*64+64], 
                                   tf_train: True})
            # Display the loss after every tenth batch
            

        # Display the loss after the epoch
       
        print('Epoch {:>3} Batch {:>2}   Training loss = {:.3f} Acc:{:.3f}'.format(epoch_i+1, batch_i+1, train_loss, accuracy))
        
        train_loss, accuracy = sess.run([l, tf_accuracy],feed_dict={tf_data: X_test, tf_labels: Y_test, 
                                   tf_train: False})
        print('Test: Epoch {:>3} Batch {:>2}   Training loss = {:.3f} Acc:{:.3f}'.format(epoch_i+1, batch_i+1, train_loss, accuracy))
        
        
    
    saver = tf.train.Saver()
    saver.save(sess, "tldetector.tf",global_step=1000)
# Out:
# Epoch   1 Batch 24   Training loss = 1.367 Acc:0.423
# Test: Epoch   1 Batch 24   Training loss = 1.100 Acc:0.551
# Epoch   2 Batch 24   Training loss = 1.217 Acc:0.423
# Test: Epoch   2 Batch 24   Training loss = 1.045 Acc:0.551
# Epoch   3 Batch 24   Training loss = 1.128 Acc:0.500
# Test: Epoch   3 Batch 24   Training loss = 0.972 Acc:0.575
# Epoch   4 Batch 24   Training loss = 1.057 Acc:0.615
# Test: Epoch   4 Batch 24   Training loss = 0.906 Acc:0.593
# Epoch   5 Batch 24   Training loss = 0.971 Acc:0.731
# Test: Epoch   5 Batch 24   Training loss = 0.834 Acc:0.629
# Epoch   6 Batch 24   Training loss = 0.995 Acc:0.654
# Test: Epoch   6 Batch 24   Training loss = 0.780 Acc:0.677
# Epoch   7 Batch 24   Training loss = 0.876 Acc:0.615
# Test: Epoch   7 Batch 24   Training loss = 0.745 Acc:0.683
# Epoch   8 Batch 24   Training loss = 0.897 Acc:0.692
# Test: Epoch   8 Batch 24   Training loss = 0.695 Acc:0.719
# Epoch   9 Batch 24   Training loss = 0.746 Acc:0.769
# Test: Epoch   9 Batch 24   Training loss = 0.643 Acc:0.766
# Epoch  10 Batch 24   Training loss = 0.401 Acc:0.923
# Test: Epoch  10 Batch 24   Training loss = 0.591 Acc:0.790
# Epoch  11 Batch 24   Training loss = 0.494 Acc:0.654
# Test: Epoch  11 Batch 24   Training loss = 0.544 Acc:0.838
# Epoch  12 Batch 24   Training loss = 0.447 Acc:0.846
# Test: Epoch  12 Batch 24   Training loss = 0.515 Acc:0.832
# Epoch  13 Batch 24   Training loss = 0.538 Acc:0.808
# Test: Epoch  13 Batch 24   Training loss = 0.446 Acc:0.856
# Epoch  14 Batch 24   Training loss = 0.431 Acc:0.808
# Test: Epoch  14 Batch 24   Training loss = 0.444 Acc:0.886
# Epoch  15 Batch 24   Training loss = 0.252 Acc:0.923
# Test: Epoch  15 Batch 24   Training loss = 0.427 Acc:0.874
# Epoch  16 Batch 24   Training loss = 0.291 Acc:0.923
# Test: Epoch  16 Batch 24   Training loss = 0.409 Acc:0.886
# Epoch  17 Batch 24   Training loss = 0.274 Acc:0.923
# Test: Epoch  17 Batch 24   Training loss = 0.400 Acc:0.880
# Epoch  18 Batch 24   Training loss = 0.196 Acc:0.962
# Test: Epoch  18 Batch 24   Training loss = 0.366 Acc:0.922
# Epoch  19 Batch 24   Training loss = 0.187 Acc:0.923
# Test: Epoch  19 Batch 24   Training loss = 0.376 Acc:0.910
# Epoch  20 Batch 24   Training loss = 0.185 Acc:0.923
# Test: Epoch  20 Batch 24   Training loss = 0.353 Acc:0.898
# Epoch  21 Batch 24   Training loss = 0.176 Acc:0.962
# Test: Epoch  21 Batch 24   Training loss = 0.348 Acc:0.892
# Epoch  22 Batch 24   Training loss = 0.257 Acc:0.923
# Test: Epoch  22 Batch 24   Training loss = 0.340 Acc:0.904
# Epoch  23 Batch 24   Training loss = 0.107 Acc:0.962
# Test: Epoch  23 Batch 24   Training loss = 0.324 Acc:0.916
# Epoch  24 Batch 24   Training loss = 0.205 Acc:0.923
# Test: Epoch  24 Batch 24   Training loss = 0.317 Acc:0.910
# Epoch  25 Batch 24   Training loss = 0.164 Acc:0.885
# Test: Epoch  25 Batch 24   Training loss = 0.317 Acc:0.928
# Epoch  26 Batch 24   Training loss = 0.138 Acc:0.962
# Test: Epoch  26 Batch 24   Training loss = 0.299 Acc:0.916
# Epoch  27 Batch 24   Training loss = 0.072 Acc:1.000
# Test: Epoch  27 Batch 24   Training loss = 0.297 Acc:0.922
# Epoch  28 Batch 24   Training loss = 0.149 Acc:0.962
# Test: Epoch  28 Batch 24   Training loss = 0.301 Acc:0.922
# Epoch  29 Batch 24   Training loss = 0.150 Acc:0.962
# Test: Epoch  29 Batch 24   Training loss = 0.303 Acc:0.934
# Epoch  30 Batch 24   Training loss = 0.074 Acc:1.000
# Test: Epoch  30 Batch 24   Training loss = 0.304 Acc:0.922
# Epoch  31 Batch 24   Training loss = 0.144 Acc:0.962
# Test: Epoch  31 Batch 24   Training loss = 0.283 Acc:0.916
# Epoch  32 Batch 24   Training loss = 0.078 Acc:1.000
# Test: Epoch  32 Batch 24   Training loss = 0.276 Acc:0.922
# Epoch  33 Batch 24   Training loss = 0.170 Acc:0.962
# Test: Epoch  33 Batch 24   Training loss = 0.265 Acc:0.922
# Epoch  34 Batch 24   Training loss = 0.051 Acc:1.000
# Test: Epoch  34 Batch 24   Training loss = 0.278 Acc:0.922
# Epoch  35 Batch 24   Training loss = 0.174 Acc:0.962
# Test: Epoch  35 Batch 24   Training loss = 0.275 Acc:0.934
# Epoch  36 Batch 24   Training loss = 0.118 Acc:0.923
# Test: Epoch  36 Batch 24   Training loss = 0.290 Acc:0.916
# Epoch  37 Batch 24   Training loss = 0.074 Acc:1.000
# Test: Epoch  37 Batch 24   Training loss = 0.256 Acc:0.922
# Epoch  38 Batch 24   Training loss = 0.067 Acc:1.000
# Test: Epoch  38 Batch 24   Training loss = 0.275 Acc:0.916
# Epoch  39 Batch 24   Training loss = 0.043 Acc:1.000
# Test: Epoch  39 Batch 24   Training loss = 0.259 Acc:0.928
# Epoch  40 Batch 24   Training loss = 0.052 Acc:1.000
# Test: Epoch  40 Batch 24   Training loss = 0.246 Acc:0.940
# Epoch  41 Batch 24   Training loss = 0.091 Acc:0.962
# Test: Epoch  41 Batch 24   Training loss = 0.228 Acc:0.934
# Epoch  42 Batch 24   Training loss = 0.082 Acc:0.962
# Test: Epoch  42 Batch 24   Training loss = 0.227 Acc:0.952
# Epoch  43 Batch 24   Training loss = 0.050 Acc:1.000
# Test: Epoch  43 Batch 24   Training loss = 0.242 Acc:0.934
# Epoch  44 Batch 24   Training loss = 0.043 Acc:1.000
# Test: Epoch  44 Batch 24   Training loss = 0.237 Acc:0.940
# Epoch  45 Batch 24   Training loss = 0.028 Acc:1.000
# Test: Epoch  45 Batch 24   Training loss = 0.219 Acc:0.940
# Epoch  46 Batch 24   Training loss = 0.045 Acc:1.000
# Test: Epoch  46 Batch 24   Training loss = 0.234 Acc:0.946
# Epoch  47 Batch 24   Training loss = 0.065 Acc:0.962
# Test: Epoch  47 Batch 24   Training loss = 0.237 Acc:0.940
# Epoch  48 Batch 24   Training loss = 0.162 Acc:0.962
# Test: Epoch  48 Batch 24   Training loss = 0.239 Acc:0.946
# Epoch  49 Batch 24   Training loss = 0.158 Acc:0.923
# Test: Epoch  49 Batch 24   Training loss = 0.242 Acc:0.934
# Epoch  50 Batch 24   Training loss = 0.024 Acc:1.000
# Test: Epoch  50 Batch 24   Training loss = 0.224 Acc:0.946
# Epoch  51 Batch 24   Training loss = 0.021 Acc:1.000
# Test: Epoch  51 Batch 24   Training loss = 0.215 Acc:0.946
# Epoch  52 Batch 24   Training loss = 0.097 Acc:0.962
# Test: Epoch  52 Batch 24   Training loss = 0.226 Acc:0.940
# Epoch  53 Batch 24   Training loss = 0.032 Acc:1.000
# Test: Epoch  53 Batch 24   Training loss = 0.244 Acc:0.940
# Epoch  54 Batch 24   Training loss = 0.030 Acc:1.000
# Test: Epoch  54 Batch 24   Training loss = 0.197 Acc:0.952
# Epoch  55 Batch 24   Training loss = 0.092 Acc:0.962
# Test: Epoch  55 Batch 24   Training loss = 0.203 Acc:0.952
# Epoch  56 Batch 24   Training loss = 0.058 Acc:1.000
# Test: Epoch  56 Batch 24   Training loss = 0.206 Acc:0.958
# Epoch  57 Batch 24   Training loss = 0.079 Acc:0.962
# Test: Epoch  57 Batch 24   Training loss = 0.243 Acc:0.946
# Epoch  58 Batch 24   Training loss = 0.028 Acc:1.000
# Test: Epoch  58 Batch 24   Training loss = 0.227 Acc:0.952
# Epoch  59 Batch 24   Training loss = 0.040 Acc:1.000
# Test: Epoch  59 Batch 24   Training loss = 0.219 Acc:0.946
# Epoch  60 Batch 24   Training loss = 0.137 Acc:0.923
# Test: Epoch  60 Batch 24   Training loss = 0.245 Acc:0.952
# Epoch  61 Batch 24   Training loss = 0.026 Acc:1.000
# Test: Epoch  61 Batch 24   Training loss = 0.253 Acc:0.940
# Epoch  62 Batch 24   Training loss = 0.020 Acc:1.000
# Test: Epoch  62 Batch 24   Training loss = 0.203 Acc:0.946
# Epoch  63 Batch 24   Training loss = 0.083 Acc:0.923
# Test: Epoch  63 Batch 24   Training loss = 0.213 Acc:0.952
# Epoch  64 Batch 24   Training loss = 0.024 Acc:1.000
# Test: Epoch  64 Batch 24   Training loss = 0.231 Acc:0.946
# Epoch  65 Batch 24   Training loss = 0.107 Acc:0.962
# Test: Epoch  65 Batch 24   Training loss = 0.183 Acc:0.946
# Epoch  66 Batch 24   Training loss = 0.013 Acc:1.000
# Test: Epoch  66 Batch 24   Training loss = 0.216 Acc:0.952
# Epoch  67 Batch 24   Training loss = 0.031 Acc:1.000
# Test: Epoch  67 Batch 24   Training loss = 0.201 Acc:0.946
# Epoch  68 Batch 24   Training loss = 0.025 Acc:1.000
# Test: Epoch  68 Batch 24   Training loss = 0.223 Acc:0.946
# Epoch  69 Batch 24   Training loss = 0.035 Acc:1.000
# Test: Epoch  69 Batch 24   Training loss = 0.199 Acc:0.958
# Epoch  70 Batch 24   Training loss = 0.028 Acc:1.000
# Test: Epoch  70 Batch 24   Training loss = 0.209 Acc:0.964
# Epoch  71 Batch 24   Training loss = 0.037 Acc:1.000
# Test: Epoch  71 Batch 24   Training loss = 0.223 Acc:0.946
# Epoch  72 Batch 24   Training loss = 0.005 Acc:1.000
# Test: Epoch  72 Batch 24   Training loss = 0.204 Acc:0.952
# Epoch  73 Batch 24   Training loss = 0.036 Acc:1.000
# Test: Epoch  73 Batch 24   Training loss = 0.189 Acc:0.958
# Epoch  74 Batch 24   Training loss = 0.115 Acc:0.962
# Test: Epoch  74 Batch 24   Training loss = 0.194 Acc:0.952
# Epoch  75 Batch 24   Training loss = 0.107 Acc:0.962
# Test: Epoch  75 Batch 24   Training loss = 0.210 Acc:0.958
# Epoch  76 Batch 24   Training loss = 0.040 Acc:0.962
# Test: Epoch  76 Batch 24   Training loss = 0.187 Acc:0.964
# Epoch  77 Batch 24   Training loss = 0.012 Acc:1.000
# Test: Epoch  77 Batch 24   Training loss = 0.218 Acc:0.952
# Epoch  78 Batch 24   Training loss = 0.005 Acc:1.000
# Test: Epoch  78 Batch 24   Training loss = 0.199 Acc:0.958
# Epoch  79 Batch 24   Training loss = 0.056 Acc:0.962
# Test: Epoch  79 Batch 24   Training loss = 0.208 Acc:0.952
# Epoch  80 Batch 24   Training loss = 0.024 Acc:1.000
# Test: Epoch  80 Batch 24   Training loss = 0.200 Acc:0.952
# Epoch  81 Batch 24   Training loss = 0.043 Acc:1.000
# Test: Epoch  81 Batch 24   Training loss = 0.232 Acc:0.946
# Epoch  82 Batch 24   Training loss = 0.010 Acc:1.000
# Test: Epoch  82 Batch 24   Training loss = 0.207 Acc:0.958
# Epoch  83 Batch 24   Training loss = 0.015 Acc:1.000
# Test: Epoch  83 Batch 24   Training loss = 0.235 Acc:0.946
# Epoch  84 Batch 24   Training loss = 0.054 Acc:1.000
# Test: Epoch  84 Batch 24   Training loss = 0.209 Acc:0.952
# Epoch  85 Batch 24   Training loss = 0.042 Acc:1.000
# Test: Epoch  85 Batch 24   Training loss = 0.217 Acc:0.958
# Epoch  86 Batch 24   Training loss = 0.011 Acc:1.000
# Test: Epoch  86 Batch 24   Training loss = 0.239 Acc:0.952
# Epoch  87 Batch 24   Training loss = 0.020 Acc:1.000
# Test: Epoch  87 Batch 24   Training loss = 0.197 Acc:0.946
# Epoch  88 Batch 24   Training loss = 0.034 Acc:1.000
# Test: Epoch  88 Batch 24   Training loss = 0.187 Acc:0.952
# Epoch  89 Batch 24   Training loss = 0.006 Acc:1.000
# Test: Epoch  89 Batch 24   Training loss = 0.207 Acc:0.946
# Epoch  90 Batch 24   Training loss = 0.213 Acc:0.962
# Test: Epoch  90 Batch 24   Training loss = 0.195 Acc:0.952
# Epoch  91 Batch 24   Training loss = 0.012 Acc:1.000
# Test: Epoch  91 Batch 24   Training loss = 0.208 Acc:0.958
# Epoch  92 Batch 24   Training loss = 0.006 Acc:1.000
# Test: Epoch  92 Batch 24   Training loss = 0.189 Acc:0.958
# Epoch  93 Batch 24   Training loss = 0.019 Acc:1.000
# Test: Epoch  93 Batch 24   Training loss = 0.220 Acc:0.964
# Epoch  94 Batch 24   Training loss = 0.003 Acc:1.000
# Test: Epoch  94 Batch 24   Training loss = 0.228 Acc:0.946
# Epoch  95 Batch 24   Training loss = 0.010 Acc:1.000
# Test: Epoch  95 Batch 24   Training loss = 0.236 Acc:0.940
# Epoch  96 Batch 24   Training loss = 0.037 Acc:1.000
# Test: Epoch  96 Batch 24   Training loss = 0.214 Acc:0.952
# Epoch  97 Batch 24   Training loss = 0.013 Acc:1.000
# Test: Epoch  97 Batch 24   Training loss = 0.225 Acc:0.952
# Epoch  98 Batch 24   Training loss = 0.042 Acc:0.962
# Test: Epoch  98 Batch 24   Training loss = 0.200 Acc:0.952
# Epoch  99 Batch 24   Training loss = 0.020 Acc:1.000
# Test: Epoch  99 Batch 24   Training loss = 0.184 Acc:0.958
# Epoch 100 Batch 24   Training loss = 0.012 Acc:1.000
# Test: Epoch 100 Batch 24   Training loss = 0.195 Acc:0.946

# %% [markdown]
# # Load model tests

# %%
import tensorflow as tf
import cv2
# %pylab inline



with tf.Session() as sess:    
    saver = tf.train.import_meta_graph('tldetector.tf-1000.meta')
    saver.restore(sess,tf.train.latest_checkpoint('./'))
    graph = tf.get_default_graph()
    
    

    tf_data = graph.get_tensor_by_name("image_input:0")
    tf_train = graph.get_tensor_by_name("train_input:0")
    tf_label = graph.get_tensor_by_name("labels_input:0")    
    sm = graph.get_tensor_by_name("output:0")
    

    testdata = (cv2.cvtColor(cv2.imread("../images/00200.jpg"), cv2.COLOR_BGR2RGB))
    
    img = sess.run([sm], feed_dict={tf_data: testdata.reshape([1,300, 400, 3]), tf_train: False})
    
    threshold = 0.95
    
    img = np.array(img)
    print("Nothing:",np.sum(img[0,0,:,:,0]>threshold))
    print("Red:",np.sum(img[0,0,:,:,1]>threshold))
    print("Green:",np.sum(img[0,0,:,:,2]>threshold))
    print("Yellow:",np.sum(img[0,0,:,:,3]>threshold))
    
    
    imshow(testdata)
    show()
    i = img[0,0,:,:,3]
    
    
    imshow(i,vmin=0, vmax=1)
    colorbar()
    show()

    def augment(raw,boolean, color):
        xx, yy = np.meshgrid(np.arange(img.shape[3]),np.arange(img.shape[2]))

        x = (xx[boolean])
        y = (yy[boolean])

        for i,j in zip(x,y):
            cv2.rectangle(testdata, (i*8,j*8), (i*8+64,j*8+64), color, 5)
            
    augment(testdata,img[0,0,:,:,1]>threshold,(255,0,0))
    augment(testdata,img[0,0,:,:,2]>threshold,(0,255,0))
    augment(testdata,img[0,0,:,:,3]>threshold,(255,255,0))
    
    imshow(testdata)
    show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# INFO:tensorflow:Restoring parameters from ./tldetector.tf-1000
# ('Nothing:', 589)
# ('Red:', 0)
# ('Green:', 26)
# ('Yellow:', 0)
