# %%
import cv2
import pandas as pd
import numpy as np

# %%
pd.read_csv("../dayTrain/dayClip1/frameAnnotationsBOX.csv", sep=";")
pd.read_csv("../dayTrain/dayClip1/frameAnnotationsBULB.csv", sep=";")
# Out:
#                              Filename Annotation tag  Upper left corner X  \
# 0     dayTraining/dayClip1--00000.png             go                  702
# 1     dayTraining/dayClip1--00000.png             go                  850
# 2     dayTraining/dayClip1--00001.png             go                  702
# 3     dayTraining/dayClip1--00001.png             go                  851
# 4     dayTraining/dayClip1--00002.png             go                  702
# 5     dayTraining/dayClip1--00002.png             go                  852
# 6     dayTraining/dayClip1--00003.png             go                  702
# 7     dayTraining/dayClip1--00003.png             go                  854
# 8     dayTraining/dayClip1--00004.png             go                  702
# 9     dayTraining/dayClip1--00004.png             go                  856
# 10    dayTraining/dayClip1--00005.png             go                  702
# 11    dayTraining/dayClip1--00005.png             go                  857
# ...

# %%
frame = cv2.imread("../dayTrain/dayClip1/frames/dayClip1--00000.png")
imshow(frame)
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
frame = cv2.rectangle(frame, (698,333), (710,358), color=(255,0,0),thickness=5)
# %pylab inline
imshow(frame)
# Out:
# Populating the interactive namespace from numpy and matplotlib
